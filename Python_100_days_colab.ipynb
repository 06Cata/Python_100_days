# %% [markdown]
# <a href="https://colab.research.google.com/github/06Cata/Python_100_days/blob/main/Python_100_days_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
name = "catalina"
print(f"hello {name}")
# Out:
# hello catalina
